# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.preprocessing import label_binarize
import xgboost as xgb

# Load preprocessed features
df_tfidf = pd.read_pickle('tfidf.pkl')
df_bow = pd.read_pickle('bow.pkl')
df_ngram = pd.read_pickle('ngram.pkl')
df_lda = pd.read_pickle('lda.pkl')

# Prepare data
labels = df_tfidf['label']
numeric_labels = df_tfidf['label_num'].values
classes = np.unique(numeric_labels)
y_binarized = label_binarize(numeric_labels, classes=classes)

# Feature matrices (drop label columns)
X_tfidf = df_tfidf.drop(['label', 'label_num'], axis=1).values
X_bow = df_bow.drop(['label', 'label_num'], axis=1).values
X_ngram = df_ngram.drop(['label', 'label_num'], axis=1).values
X_lda = df_lda.drop(['label', 'label_num'], axis=1).values

# Combine features function
def combine_features(*arrays):
    return np.hstack(arrays)

# Dictionary of feature sets (include individual and combinations)
feature_sets = {
    'TF-IDF': X_tfidf,
    'BoW': X_bow,
    'N-grams': X_ngram,
    'LDA': X_lda,
    'TF-IDF + BoW': combine_features(X_tfidf, X_bow),
    'TF-IDF + N-grams': combine_features(X_tfidf, X_ngram),
    'TF-IDF + LDA': combine_features(X_tfidf, X_lda),
    'BoW + N-grams': combine_features(X_bow, X_ngram),
    'BoW + LDA': combine_features(X_bow, X_lda),
    'N-grams + LDA': combine_features(X_ngram, X_lda),
    'TF-IDF + BoW + N-grams': combine_features(X_tfidf, X_bow, X_ngram),
    'TF-IDF + BoW + LDA': combine_features(X_tfidf, X_bow, X_lda),
    'TF-IDF + N-grams + LDA': combine_features(X_tfidf, X_ngram, X_lda),
    'BoW + N-grams + LDA': combine_features(X_bow, X_ngram, X_lda),
    'All Combined': combine_features(X_tfidf, X_bow, X_ngram, X_lda),
}

# Set up 10-fold cross-validation
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

results = {}

for name, X in feature_sets.items():
    accuracies = []
    roc_aucs = []

    print(f"Training and evaluating with feature set: {name}")
    for fold, (train_index, test_index) in enumerate(kf.split(X, numeric_labels), 1):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = numeric_labels[train_index], numeric_labels[test_index]
        y_test_binarized = y_binarized[test_index]

        # Initialize XGBoost classifier
        model = xgb.XGBClassifier(eval_metric='mlogloss', random_state=42)
        model.fit(X_train, y_train)

        # Predict
        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)

        # Metrics
        acc = accuracy_score(y_test, y_pred)
        roc_auc = roc_auc_score(y_test_binarized, y_proba, multi_class='ovr')

        accuracies.append(acc)
        roc_aucs.append(roc_auc)

        print(f"  Fold {fold}: Accuracy = {acc:.4f}, ROC-AUC = {roc_auc:.4f}")

    avg_acc = np.mean(accuracies)
    avg_roc = np.mean(roc_aucs)
    results[name] = (avg_acc, avg_roc)
    print(f"Average Accuracy: {avg_acc:.4f}, Average ROC-AUC: {avg_roc:.4f}\n")

# Summary of all feature sets
print("\nSummary of Results:")
print(f"{'Feature Set':<30} {'Accuracy':<10} {'ROC-AUC':<10}")
for key, (acc, roc) in results.items():
    print(f"{key:<30} {acc:<10.4f} {roc:<10.4f}")

# Select the best feature set by accuracy
best_feature_set = max(results.items(), key=lambda x: x[1][0])
best_name, (best_acc, best_roc) = best_feature_set

print("\n=== Best Feature Set ===")
print(f"Feature Set: {best_name}")
print(f"Accuracy: {best_acc:.4f}")
print(f"ROC-AUC: {best_roc:.4f}")
# Out:
# Training and evaluating with feature set: TF-IDF
#   Fold 1: Accuracy = 0.8600, ROC-AUC = 0.9770
#   Fold 2: Accuracy = 0.9200, ROC-AUC = 0.9897
#   Fold 3: Accuracy = 0.9700, ROC-AUC = 0.9990
#   Fold 4: Accuracy = 0.8800, ROC-AUC = 0.9821
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9851
#   Fold 6: Accuracy = 0.8700, ROC-AUC = 0.9910
#   Fold 7: Accuracy = 0.9100, ROC-AUC = 0.9887
#   Fold 8: Accuracy = 0.9000, ROC-AUC = 0.9835
#   Fold 9: Accuracy = 0.8700, ROC-AUC = 0.9840
#   Fold 10: Accuracy = 0.8300, ROC-AUC = 0.9744
# Average Accuracy: 0.8900, Average ROC-AUC: 0.9855
#
# Training and evaluating with feature set: BoW
#   Fold 1: Accuracy = 0.8900, ROC-AUC = 0.9829
#   Fold 2: Accuracy = 0.9100, ROC-AUC = 0.9945
#   Fold 3: Accuracy = 0.9600, ROC-AUC = 0.9990
#   Fold 4: Accuracy = 0.9200, ROC-AUC = 0.9890
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9896
#   Fold 6: Accuracy = 0.9200, ROC-AUC = 0.9949
#   Fold 7: Accuracy = 0.9300, ROC-AUC = 0.9875
#   Fold 8: Accuracy = 0.9100, ROC-AUC = 0.9834
#   Fold 9: Accuracy = 0.8900, ROC-AUC = 0.9865
#   Fold 10: Accuracy = 0.8300, ROC-AUC = 0.9771
# Average Accuracy: 0.9050, Average ROC-AUC: 0.9884
#
# Training and evaluating with feature set: N-grams
#   Fold 1: Accuracy = 0.8300, ROC-AUC = 0.9623
#   Fold 2: Accuracy = 0.7900, ROC-AUC = 0.9585
#   Fold 3: Accuracy = 0.7800, ROC-AUC = 0.9714
#   Fold 4: Accuracy = 0.8200, ROC-AUC = 0.9689
#   Fold 5: Accuracy = 0.8200, ROC-AUC = 0.9689
#   Fold 6: Accuracy = 0.7900, ROC-AUC = 0.9546
#   Fold 7: Accuracy = 0.7400, ROC-AUC = 0.9374
#   Fold 8: Accuracy = 0.7800, ROC-AUC = 0.9329
#   Fold 9: Accuracy = 0.7500, ROC-AUC = 0.9480
#   Fold 10: Accuracy = 0.7200, ROC-AUC = 0.9347
# Average Accuracy: 0.7820, Average ROC-AUC: 0.9537
#
# Training and evaluating with feature set: LDA
#   Fold 1: Accuracy = 0.4900, ROC-AUC = 0.8020
#   Fold 2: Accuracy = 0.5900, ROC-AUC = 0.8349
#   Fold 3: Accuracy = 0.5100, ROC-AUC = 0.8609
#   Fold 4: Accuracy = 0.4900, ROC-AUC = 0.8085
#   Fold 5: Accuracy = 0.4600, ROC-AUC = 0.8088
#   Fold 6: Accuracy = 0.6200, ROC-AUC = 0.8361
#   Fold 7: Accuracy = 0.5800, ROC-AUC = 0.8219
#   Fold 8: Accuracy = 0.5000, ROC-AUC = 0.8479
#   Fold 9: Accuracy = 0.5300, ROC-AUC = 0.8201
#   Fold 10: Accuracy = 0.5400, ROC-AUC = 0.8384
# Average Accuracy: 0.5310, Average ROC-AUC: 0.8279
#
# Training and evaluating with feature set: TF-IDF + BoW
#   Fold 1: Accuracy = 0.8500, ROC-AUC = 0.9761
#   Fold 2: Accuracy = 0.9200, ROC-AUC = 0.9897
#   Fold 3: Accuracy = 0.9500, ROC-AUC = 0.9984
#   Fold 4: Accuracy = 0.8900, ROC-AUC = 0.9815
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9874
#   Fold 6: Accuracy = 0.8800, ROC-AUC = 0.9912
#   Fold 7: Accuracy = 0.9100, ROC-AUC = 0.9902
#   Fold 8: Accuracy = 0.9000, ROC-AUC = 0.9834
#   Fold 9: Accuracy = 0.8600, ROC-AUC = 0.9832
#   Fold 10: Accuracy = 0.8400, ROC-AUC = 0.9764
# Average Accuracy: 0.8890, Average ROC-AUC: 0.9858
#
# Training and evaluating with feature set: TF-IDF + N-grams
#   Fold 1: Accuracy = 0.8500, ROC-AUC = 0.9762
#   Fold 2: Accuracy = 0.9200, ROC-AUC = 0.9894
#   Fold 3: Accuracy = 0.9600, ROC-AUC = 0.9990
#   Fold 4: Accuracy = 0.9000, ROC-AUC = 0.9800
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9875
#   Fold 6: Accuracy = 0.8800, ROC-AUC = 0.9926
#   Fold 7: Accuracy = 0.9100, ROC-AUC = 0.9885
#   Fold 8: Accuracy = 0.9000, ROC-AUC = 0.9822
#   Fold 9: Accuracy = 0.8800, ROC-AUC = 0.9844
#   Fold 10: Accuracy = 0.8200, ROC-AUC = 0.9732
# Average Accuracy: 0.8910, Average ROC-AUC: 0.9853
#
# Training and evaluating with feature set: TF-IDF + LDA
#   Fold 1: Accuracy = 0.8600, ROC-AUC = 0.9737
#   Fold 2: Accuracy = 0.9000, ROC-AUC = 0.9899
#   Fold 3: Accuracy = 0.9500, ROC-AUC = 0.9995
#   Fold 4: Accuracy = 0.9100, ROC-AUC = 0.9840
#   Fold 5: Accuracy = 0.9000, ROC-AUC = 0.9924
#   Fold 6: Accuracy = 0.9200, ROC-AUC = 0.9941
#   Fold 7: Accuracy = 0.9100, ROC-AUC = 0.9894
#   Fold 8: Accuracy = 0.9200, ROC-AUC = 0.9819
#   Fold 9: Accuracy = 0.8400, ROC-AUC = 0.9853
#   Fold 10: Accuracy = 0.8300, ROC-AUC = 0.9715
# Average Accuracy: 0.8940, Average ROC-AUC: 0.9862
#
# Training and evaluating with feature set: BoW + N-grams
#   Fold 1: Accuracy = 0.8900, ROC-AUC = 0.9817
#   Fold 2: Accuracy = 0.9100, ROC-AUC = 0.9945
#   Fold 3: Accuracy = 0.9600, ROC-AUC = 0.9993
#   Fold 4: Accuracy = 0.9200, ROC-AUC = 0.9908
#   Fold 5: Accuracy = 0.9000, ROC-AUC = 0.9872
#   Fold 6: Accuracy = 0.9200, ROC-AUC = 0.9956
#   Fold 7: Accuracy = 0.9000, ROC-AUC = 0.9864
#   Fold 8: Accuracy = 0.9000, ROC-AUC = 0.9831
#   Fold 9: Accuracy = 0.8700, ROC-AUC = 0.9866
#   Fold 10: Accuracy = 0.8500, ROC-AUC = 0.9762
# Average Accuracy: 0.9020, Average ROC-AUC: 0.9882
#
# Training and evaluating with feature set: BoW + LDA
#   Fold 1: Accuracy = 0.8900, ROC-AUC = 0.9756
#   Fold 2: Accuracy = 0.9000, ROC-AUC = 0.9931
#   Fold 3: Accuracy = 0.9600, ROC-AUC = 0.9994
#   Fold 4: Accuracy = 0.9100, ROC-AUC = 0.9874
#   Fold 5: Accuracy = 0.9000, ROC-AUC = 0.9919
#   Fold 6: Accuracy = 0.9300, ROC-AUC = 0.9955
#   Fold 7: Accuracy = 0.9100, ROC-AUC = 0.9859
#   Fold 8: Accuracy = 0.8900, ROC-AUC = 0.9840
#   Fold 9: Accuracy = 0.8900, ROC-AUC = 0.9831
#   Fold 10: Accuracy = 0.8600, ROC-AUC = 0.9769
# Average Accuracy: 0.9040, Average ROC-AUC: 0.9873
#
# Training and evaluating with feature set: N-grams + LDA
#   Fold 1: Accuracy = 0.7300, ROC-AUC = 0.9303
#   Fold 2: Accuracy = 0.7600, ROC-AUC = 0.9390
#   Fold 3: Accuracy = 0.8100, ROC-AUC = 0.9720
#   Fold 4: Accuracy = 0.8300, ROC-AUC = 0.9534
#   Fold 5: Accuracy = 0.7100, ROC-AUC = 0.9455
#   Fold 6: Accuracy = 0.7600, ROC-AUC = 0.9536
#   Fold 7: Accuracy = 0.7700, ROC-AUC = 0.9424
#   Fold 8: Accuracy = 0.7500, ROC-AUC = 0.9316
#   Fold 9: Accuracy = 0.7200, ROC-AUC = 0.9356
#   Fold 10: Accuracy = 0.7500, ROC-AUC = 0.9381
# Average Accuracy: 0.7590, Average ROC-AUC: 0.9441
#
# Training and evaluating with feature set: TF-IDF + BoW + N-grams
#   Fold 1: Accuracy = 0.8500, ROC-AUC = 0.9753
#   Fold 2: Accuracy = 0.9300, ROC-AUC = 0.9920
#   Fold 3: Accuracy = 0.9600, ROC-AUC = 0.9985
#   Fold 4: Accuracy = 0.9000, ROC-AUC = 0.9822
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9881
#   Fold 6: Accuracy = 0.8700, ROC-AUC = 0.9924
#   Fold 7: Accuracy = 0.8900, ROC-AUC = 0.9879
#   Fold 8: Accuracy = 0.8900, ROC-AUC = 0.9799
#   Fold 9: Accuracy = 0.8600, ROC-AUC = 0.9852
#   Fold 10: Accuracy = 0.8300, ROC-AUC = 0.9734
# Average Accuracy: 0.8870, Average ROC-AUC: 0.9855
#
# Training and evaluating with feature set: TF-IDF + BoW + LDA
#   Fold 1: Accuracy = 0.8600, ROC-AUC = 0.9742
#   Fold 2: Accuracy = 0.9000, ROC-AUC = 0.9892
#   Fold 3: Accuracy = 0.9500, ROC-AUC = 0.9995
#   Fold 4: Accuracy = 0.8700, ROC-AUC = 0.9834
#   Fold 5: Accuracy = 0.9100, ROC-AUC = 0.9935
#   Fold 6: Accuracy = 0.9200, ROC-AUC = 0.9939
#   Fold 7: Accuracy = 0.9000, ROC-AUC = 0.9876
#   Fold 8: Accuracy = 0.8900, ROC-AUC = 0.9817
#   Fold 9: Accuracy = 0.8600, ROC-AUC = 0.9839
#   Fold 10: Accuracy = 0.8500, ROC-AUC = 0.9769
# Average Accuracy: 0.8910, Average ROC-AUC: 0.9864
#
# Training and evaluating with feature set: TF-IDF + N-grams + LDA
#   Fold 1: Accuracy = 0.8700, ROC-AUC = 0.9727
#   Fold 2: Accuracy = 0.9100, ROC-AUC = 0.9911
#   Fold 3: Accuracy = 0.9500, ROC-AUC = 0.9996
#   Fold 4: Accuracy = 0.9000, ROC-AUC = 0.9844
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9914
#   Fold 6: Accuracy = 0.9100, ROC-AUC = 0.9946
#   Fold 7: Accuracy = 0.9100, ROC-AUC = 0.9890
#   Fold 8: Accuracy = 0.9000, ROC-AUC = 0.9814
#   Fold 9: Accuracy = 0.8600, ROC-AUC = 0.9846
#   Fold 10: Accuracy = 0.8500, ROC-AUC = 0.9717
# Average Accuracy: 0.8950, Average ROC-AUC: 0.9861
#
# Training and evaluating with feature set: BoW + N-grams + LDA
#   Fold 1: Accuracy = 0.9000, ROC-AUC = 0.9741
#   Fold 2: Accuracy = 0.9100, ROC-AUC = 0.9938
#   Fold 3: Accuracy = 0.9700, ROC-AUC = 0.9994
#   Fold 4: Accuracy = 0.9200, ROC-AUC = 0.9869
#   Fold 5: Accuracy = 0.9000, ROC-AUC = 0.9892
#   Fold 6: Accuracy = 0.9300, ROC-AUC = 0.9955
#   Fold 7: Accuracy = 0.9200, ROC-AUC = 0.9880
#   Fold 8: Accuracy = 0.8800, ROC-AUC = 0.9843
#   Fold 9: Accuracy = 0.9000, ROC-AUC = 0.9860
#   Fold 10: Accuracy = 0.8600, ROC-AUC = 0.9788
# Average Accuracy: 0.9090, Average ROC-AUC: 0.9876
#
# Training and evaluating with feature set: All Combined
#   Fold 1: Accuracy = 0.8700, ROC-AUC = 0.9731
#   Fold 2: Accuracy = 0.9100, ROC-AUC = 0.9901
#   Fold 3: Accuracy = 0.9500, ROC-AUC = 0.9995
#   Fold 4: Accuracy = 0.8900, ROC-AUC = 0.9834
#   Fold 5: Accuracy = 0.8900, ROC-AUC = 0.9919
#   Fold 6: Accuracy = 0.9100, ROC-AUC = 0.9955
#   Fold 7: Accuracy = 0.9000, ROC-AUC = 0.9885
#   Fold 8: Accuracy = 0.8800, ROC-AUC = 0.9812
#   Fold 9: Accuracy = 0.8500, ROC-AUC = 0.9852
#   Fold 10: Accuracy = 0.8300, ROC-AUC = 0.9744
# Average Accuracy: 0.8880, Average ROC-AUC: 0.9863
#
#
# Summary of Results:
# Feature Set                    Accuracy   ROC-AUC
# TF-IDF                         0.8900     0.9855
# BoW                            0.9050     0.9884
# N-grams                        0.7820     0.9537
# LDA                            0.5310     0.8279
# TF-IDF + BoW                   0.8890     0.9858
# TF-IDF + N-grams               0.8910     0.9853
# TF-IDF + LDA                   0.8940     0.9862
# BoW + N-grams                  0.9020     0.9882
# BoW + LDA                      0.9040     0.9873
# N-grams + LDA                  0.7590     0.9441
# TF-IDF + BoW + N-grams         0.8870     0.9855
# TF-IDF + BoW + LDA             0.8910     0.9864
# TF-IDF + N-grams + LDA         0.8950     0.9861
# BoW + N-grams + LDA            0.9090     0.9876
# All Combined                   0.8880     0.9863
#
# === Best Feature Set ===
# Feature Set: BoW + N-grams + LDA
# Accuracy: 0.9090
# ROC-AUC: 0.9876

# %%
# Save results to a file for later comparison
import pickle
import os

xgb_file = "xgboost_results.pkl"
with open(xgb_file, "wb") as f:
    pickle.dump(results, f)

# Confirm file was saved
if os.path.exists(xgb_file):
    print(f"XGBoost results successfully saved to '{xgb_file}'.")
else:
    print(f"Failed to save XGBoost results.")
# Out:
# XGBoost results successfully saved to 'xgboost_results.pkl'.
